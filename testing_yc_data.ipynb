# %%
import us_yc_market_data as yc

import importlib

importlib.reload(yc)
# Out:
# <module 'us_yc_market_data' from '/Users/archibaldgonah/Desktop/Financial Engineering/pairs_trading_algo/us_yc_market_data.py'>

# %%
curve = yc.us_yield_curve_market_data(1)

curve.us_yield_curve()
curve.merge_data()

df = curve.df()

df
# Out:
#             Repo_Rate_US  One_Month_US  Three_Month_US  Six_Month_US  \
# 2025-06-25          4.33          4.21            4.38          4.26
# 2025-06-26          4.33          4.11            4.39          4.26
# 2025-06-27          4.33          4.19            4.39          4.26
# 2025-06-28          4.33          4.19            4.39          4.26
# 2025-06-29          4.33          4.19            4.39          4.26
# ...                  ...           ...             ...           ...
# 2026-06-19          3.63          3.69            3.83          3.92
# 2026-06-20          3.63          3.69            3.83          3.92
# 2026-06-21          3.63          3.69            3.83          3.92
# 2026-06-22          3.63          3.66            3.85          3.98
# 2026-06-23          3.63          3.65            3.85          3.96
#
#             One_Year_US  Two_Year_US  Five_Year_US  Ten_Year_US  \
# 2025-06-25         3.99         3.74          3.83         4.29
# ...
