# %%
import us_yc_market_data as yc

import importlib

importlib.reload(yc)
# Out:
# <module 'us_yc_market_data' from '/Users/archibaldgonah/Desktop/Financial Engineering/pairs_trading_algo/us_yc_market_data.py'>

# %%
curve = yc.USYieldCurveMarketData(5)

df = curve.data
df.head()
# Out:
#             Repo  One_Month_US  Three_Month_US  Six_Month_US  One_Year_US  \
# 2021-06-25   0.1          0.05            0.06          0.06         0.09
# 2021-06-26   0.1          0.05            0.06          0.06         0.09
# 2021-06-27   0.1          0.05            0.06          0.06         0.09
# 2021-06-28   0.1          0.04            0.05          0.06         0.08
# 2021-06-29   0.1          0.04            0.04          0.06         0.08
#
#             Two_Year_US  Three_year_US  Five_Year_US  Ten_Year_US  \
# 2021-06-25         0.28           0.48          0.92         1.54
# 2021-06-26         0.28           0.48          0.92         1.54
# 2021-06-27         0.28           0.48          0.92         1.54
# 2021-06-28         0.25           0.47          0.90         1.49
# 2021-06-29         0.27           0.47          0.89         1.49
#
#             Twenty_Year_US  Thirty_Year_US
# 2021-06-25            2.09            2.16
# ...
