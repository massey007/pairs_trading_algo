# %%
import us_yc_market_data as yc

import importlib

importlib.reload(yc)
# Out:
# <module 'us_yc_market_data' from '/Users/archibaldgonah/Desktop/Financial Engineering/pairs_trading_algo/us_yc_market_data.py'>

# %%
start_date = '2025-01-01'
end_date = '2025-12-31'

df = yc.us_yield_curve_market_data(start_date, end_date)

df.dataframe().head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 6
#       2 end_date = '2025-12-31'
#       4 df = yc.us_yield_curve_market_data(start_date, end_date)
# ----> 6 df.dataframe().head()
#
# AttributeError: 'us_yield_curve_market_data' object has no attribute 'dataframe'
